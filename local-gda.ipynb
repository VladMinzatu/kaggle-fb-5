# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the training data

# %%
train_df = pd.read_csv('data/train.csv', index_col='row_id', dtype={"place_id": str})

# %% [markdown]
# According to the discussions in the forum, the time is most likely measured in minutes, so let's extract some temporal features that might be useful.

# %% [markdown]
# ### Add temporal features

# %%
train_df['hour_of_day'] = (train_df['time'] / 60) % 24
train_df['day_of_week'] = (train_df['time'] / 60 / 24) % 7 # The offset shouldn't matter

# %% [markdown]
# ### Group by place id

# %%
gb = train_df.groupby('place_id')
place_dfs = [gb.get_group(x) for x in gb.groups]

# %% [markdown]
# We could convert these new columns to ints, but leaving them as they are now might come in handy.

# %% [markdown]
# ### Filter out places with low number of check-ins

# %%
filtered_place_dfs = [x for x in place_dfs if x.size >= 10]
len(filtered_place_dfs)
# Out:
# 108144

# %% [markdown]
# ### Compute Gaussian per place id

# %%
def get_gauss(df):
    X = df[['x', 'y', 'hour_of_day']].values
    if X.shape[0] <= 5:
        return None
    mean = np.mean(X, axis = 0)
    S = 1/X.shape[0] * np.dot((X - mean).T,(X - mean))
    return (df['place_id'].unique()[0], multivariate_normal(mean, S))
    
dists = [get_gauss(place_dfs[i]) for i in range(len(place_dfs))]

# %%
dists_dict = dict([d for d in dists if d != None])

# %% [markdown]
# ### Assign Gaussians to grid

# %%
def as_str(x,y):
    return str(round(abs(x), 1)) + str(round(abs(y), 1))

# %%
the_grid = {as_str(x,y):[] for x in np.arange(0,10.1,0.1) for y in np.arange(0,10.1,0.1)}
devs = 1
for place in dists_dict.keys():
    dist = dists_dict[place]
    min_x = dist.mean[0] - devs * dist.cov[0][0]
    max_x = dist.mean[0] + devs * dist.cov[0][0]
    min_y = dist.mean[1] - devs * dist.cov[1][1]
    max_y = dist.mean[1] + devs * dist.cov[1][1]
    for x in np.arange(min_x, max_x, 0.1):
        for y in np.arange(min_y, max_y, 0.1):
            if max_y < 10.0 and max_x < 10.0 and min_x >= 0 and min_y >= 0:
                the_grid[as_str(x,y)].append(place)

# %%
def predict(x, y, h, grid, dists_dict):
    candidates = grid[as_str(x, y)]
    scored = [(p, dists_dict[p].pdf([x,y,h])) for p in candidates]
    return sorted(scored, key=lambda x: -x[1])
        
def format(sorted_list):
    return ' '.join([s[0] for s in sorted_list[:3]])

format(predict(8.3078, 7.0407, 16.12, the_grid, dists_dict))
# Out:
# '3108247878 5274648504 8056933091'

# %% [markdown]
# ### Make predictions

# %%
test_df = pd.read_csv('data/test.csv', index_col='row_id')

# %%
test_df['hour_of_day'] = (test_df['time'] / 60) % 24

# %%
test_df
# Out:
#               x       y  accuracy     time  hour_of_day
# row_id
# 0        0.1675  1.3608       107   930883    10.716667
# 1        7.3909  2.5301        35   893017     3.616667
# 2        8.0978  2.3473        62   976933    10.216667
# 3        0.9990  1.0591        62   907285     1.416667
# 4        0.6670  9.7254        40   914399    23.983333
# 5        0.1771  0.0022       161   814077     7.950000
# 6        5.5299  4.6581         2   930759     8.650000
# 7        8.6021  3.1744         4   862115    16.583333
# 8        4.2250  6.3435       162   787391    19.183333
# 9        0.6489  6.2611        39   793166    19.433333
# 10       2.7546  6.6373       315   807936     1.600000
# 11       0.9998  7.4121        80   913991    17.183333
# 12       4.9477  6.4959         7   938599    19.316667
# 13       5.0336  1.2666        83   800780     2.333333
# 14       0.9480  4.4362        59   892117    12.616667
# 15       0.2898  3.0031        57   909801    19.350000
# 16       5.2386  1.8262        52   867042     2.700000
# 17       2.9797  7.7333       170   822650     6.833333
# 18       5.0956  0.1904        56   841934    16.233333
# 19       2.7856  1.7072        61   884954    13.233333
# 20       3.6321  2.2853        67   905857     1.616667
# 21       9.9039  5.9419        76   842668     4.466667
# 22       5.5745  3.4077        30   863513    15.883333
# 23       2.4119  6.3321        70   867179     4.983333
# 24       3.0635  4.2433        78   855147    20.450000
# 25       4.8934  3.7615       237   820307    15.783333
# 26       0.9999  9.9553       844   809976    11.600000
# 27       9.4647  2.0808       638   872145    15.750000
# 28       5.0168  6.4633        90   861390     4.500000
# 29       0.1378  6.3284        25   791750    19.833333
# ...         ...     ...       ...      ...          ...
# 8607200  8.4712  9.9202       534   898406    21.433333
# 8607201  3.9862  3.5731        78   931702     0.366667
# 8607202  3.6345  8.6361        54   798635    14.583333
# 8607203  3.9515  3.7811       103   837065     7.083333
# 8607204  4.1147  0.5550        36   858665     7.083333
# 8607205  3.7607  5.7430        27   818213     4.883333
# 8607206  5.2770  0.2624        39   963037    18.616667
# 8607207  4.2543  0.8777        76   838057    23.616667
# 8607208  4.3629  3.5433       102   795363     8.050000
# 8607209  5.2537  8.9852        70   848406     4.100000
# 8607210  6.6662  3.7099         2   801908    21.133333
# 8607211  3.5009  3.9504       967   798074     5.233333
# 8607212  4.7167  4.7857        12   967946     4.433333
# 8607213  9.3196  4.1151        71  1003544    21.733333
# 8607214  6.4525  1.8398        62   854084     2.733333
# 8607215  8.3778  5.5490        30   889128    10.800000
# 8607216  9.8450  3.9206        92   826785     3.750000
# 8607217  9.3638  5.9340        26   809470     3.166667
# 8607218  0.0945  8.5868        65   906535    12.916667
# 8607219  9.4804  3.9249        10   900181     3.016667
# 8607220  7.1715  1.8787        49   973675     3.916667
# 8607221  2.0729  7.4822        17   789812    11.533333
# 8607222  0.5067  1.8705        36   931820     2.333333
# 8607223  9.8678  6.1212       147   913980    17.000000
# 8607224  4.0991  0.7243        20   910040    23.333333
# 8607225  4.1206  5.2443        58   882527    20.783333
# 8607226  5.1170  5.7695        60   984517    16.616667
# 8607227  6.6409  8.3626        19   814024     7.066667
# 8607228  6.4190  2.9985        68   862916     5.933333
# 8607229  8.1017  7.8736         1   845096    20.933333
#
# [8607230 rows x 5 columns]

# %%
test_df["place_id"] = test_df.apply(lambda r: format(predict(r["x"], r["y"], r["hour_of_day"], the_grid, dists_dict)), axis=1)

# %%
# !rm submission.csv
test_df[["place_id"]].to_csv("submission.csv", index=True)
