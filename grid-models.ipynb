# %%
import pandas as pd
from sklearn.cross_validation import train_test_split
import xgboost as xgb
import numpy as np

import glob

# %%
def predict(clf, places, check_in):
    proba = clf.predict_proba(np.array([[check_in["x"],check_in["y"],check_in["accuracy"],check_in["hour_of_day"],check_in["day_of_week"]]]))[0]
    return ' '.join([p[0] for p in sorted(zip(places, proba), key=lambda x: -x[1])[:3]])

# %%
def make_predictions(suffix):
    print("Reading training data")
    train_df = pd.read_csv('data/grid_data/train/train_' + suffix, dtype={"place_id": str})
    places = train_df['place_id'].unique()
    places_index = {p[1]:p[0] for p in enumerate(places)}
    
    X_train = train_df[['x', 'y', 'accuracy', 'hour_of_day', 'day_of_week']].values
    y_train = train_df.apply(lambda r: places_index[r["place_id"]], axis=1).values
    
    print("Training classifier")
    clf = xgb.XGBClassifier(max_depth=10, n_estimators=15, learning_rate=0.1, objective='multi:softprob',
                        nthread=4, subsample=1.0, colsample_bytree=0.85, silent=1, seed=7171)
    clf.fit(X_train, y_train)
    
    print("Making submission")
    test_df = pd.read_csv('data/grid_data/test/test_' + suffix)
    test_df["place_id"] = test_df.apply(lambda r: predict(clf, places, r), axis=1)
    test_df[["row_id", "place_id"]].to_csv("data/grid_data/submission/submission_" + suffix, index=False, header=False)

# %%
for i in range(9800, 10000):
    suffix = glob.glob("data/grid_data/train/train_" + str(i) + "_*")[0][27:]
    print('Making predictions for suffix ' + suffix)
    make_predictions(suffix)
# Out:
# Making predictions for suffix 9800_52x55.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9801_64x90.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9802_1x32.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9803_53x53.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9804_35x98.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9805_55x33.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9806_97x83.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9807_90x13.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9808_41x35.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9809_76x98.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9810_44x82.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9811_92x62.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9812_99x59.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9813_76x61.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9814_87x12.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9815_59x88.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9816_8x32.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9817_0x18.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9818_8x18.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9819_29x33.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9820_20x60.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9821_22x63.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9822_13x71.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9823_24x66.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9824_37x0.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9825_97x96.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9826_30x88.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9827_14x94.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9828_15x30.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9829_54x89.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9830_80x76.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9831_12x30.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9832_91x50.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9833_83x20.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9834_70x90.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9835_26x11.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9836_33x39.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9837_68x3.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9838_88x81.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9839_38x96.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9840_23x94.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9841_48x98.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9842_80x8.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9843_85x46.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9844_80x74.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9845_92x1.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9846_41x69.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9847_60x17.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9848_16x96.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9849_51x82.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9850_79x42.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9851_0x31.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9852_65x28.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9853_81x65.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9854_75x72.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9855_85x79.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 9856_75x75.csv
# Reading training data
# Training classifier
# Making submission
# Making predictions for suffix 